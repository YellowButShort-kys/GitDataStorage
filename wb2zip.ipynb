# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df
# Out:
#                     Country Name Country Code  1960        1961        1962  \
# 0                          Aruba          ABW   0.0       180.0       180.0
# 1    Africa Eastern and Southern          AFE   0.0  15106741.0  15106741.0
# 2                    Afghanistan          AFG   0.0    652860.0    652860.0
# 3     Africa Western and Central          AFW   0.0   9166270.0   9166270.0
# 4                         Angola          AGO   0.0   1246700.0   1246700.0
# ..                           ...          ...   ...         ...         ...
# 261                       Kosovo          XKX   0.0    265405.0    265405.0
# 262                  Yemen, Rep.          YEM   0.0    527970.0    527970.0
# 263                 South Africa          ZAF   0.0   1219090.0   1219090.0
# 264                       Zambia          ZMB   0.0    752610.0    752610.0
# 265                     Zimbabwe          ZWE   0.0    390760.0    390760.0
#
# ...

# %%
df = pd.read_csv("C:/Trash/_MONEY/GitDataStorage/GitDataStorage/co2.csv", skiprows=3)
#df.fillna(0, inplace=True)

df.drop("Indicator Name", axis=1, inplace=True)
df.drop("Indicator Code", axis=1, inplace=True)

df.drop("Unnamed: 67", axis=1, inplace=True)
df.interpolate(inplace=True)
df.fillna(0, inplace=True)
df.to_json("C:/Trash/_MONEY/GitDataStorage/GitDataStorage/data/co2.json", orient="records")

'''
for index, row in df.iterrows():
    nrow = row[4:].divide(1000000)
    px = 1/plt.rcParams['figure.dpi']  
    fig, ax = plt.subplots(figsize=(350*px, 200*px))
    plt.ticklabel_format(style='plain')

    ax.spines.top.set_visible(False)
    ax.spines.right.set_visible(False)
    ax.plot(nrow)
    ax.set_ylabel(row["Indicator Name"] + " in Millions")
    ax.set_xlabel('Year (0 means no data)')
    
    plt.text(.01, .99, row["Country Name"], ha='left', va='top', transform=ax.transAxes, fontsize = "xx-large")

    
    fig.autofmt_xdate()
    fig.tight_layout() 
    n = 5
    [l.set_visible(False) for (i,l) in enumerate(ax.xaxis.get_ticklabels()) if i % n != 0]

    #plt.show()
    plt.savefig("gdp/plots/"+row["Country Code"]+'.png', transparent= True)
    print("{} / {}".format(index, len(df)-1))
    plt.close()
'''
# Out:
# '\nfor index, row in df.iterrows():\n    nrow = row[4:].divide(1000000)\n    px = 1/plt.rcParams[\'figure.dpi\']  \n    fig, ax = plt.subplots(figsize=(350*px, 200*px))\n    plt.ticklabel_format(style=\'plain\')\n\n    ax.spines.top.set_visible(False)\n    ax.spines.right.set_visible(False)\n    ax.plot(nrow)\n    ax.set_ylabel(row["Indicator Name"] + " in Millions")\n    ax.set_xlabel(\'Year (0 means no data)\')\n    \n    plt.text(.01, .99, row["Country Name"], ha=\'left\', va=\'top\', transform=ax.transAxes, fontsize = "xx-large")\n\n    \n    fig.autofmt_xdate()\n    fig.tight_layout() \n    n = 5\n    [l.set_visible(False) for (i,l) in enumerate(ax.xaxis.get_ticklabels()) if i % n != 0]\n\n    #plt.show()\n    plt.savefig("gdp/plots/"+row["Country Code"]+\'.png\', transparent= True)\n    print("{} / {}".format(index, len(df)-1))\n    plt.close()\n'
